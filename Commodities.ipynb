# %%
# Prepare your workstation.
import pandas as pd
import numpy as np

# %%
#Import CSV files.
Gold = pd.read_csv('gold_stocks_price.csv')
Oil = pd.read_csv('oil_price.csv')

print(Gold.shape)
print(Oil.shape)
# Out:
# (1718, 81)
# (1844, 6)

# %%
#View the datatypes.
print(Gold.dtypes)
print(Oil.dtypes)
# Out:
# Date              object
# Open             float64
# High             float64
# Low              float64
# Close            float64
#                   ...
# USO_High         float64
# USO_Low          float64
# USO_Close        float64
# USO_Adj Close    float64
# USO_Volume         int64
# Length: 81, dtype: object
# Date      object
# Price    float64
# Open     float64
# High     float64
# Low      float64
# Vol.      object
# dtype: object

# %%
#View the Dataframes.
print(Gold)
print(Oil)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2011-12-15  154.740005  154.949997  151.710007  152.330002  152.330002
# 1     2011-12-16  154.309998  155.369995  153.899994  155.229996  155.229996
# 2     2011-12-19  155.479996  155.860001  154.360001  154.869995  154.869995
# 3     2011-12-20  156.820007  157.429993  156.580002  156.979996  156.979996
# 4     2011-12-21  156.979996  157.529999  156.130005  157.160004  157.160004
# ...          ...         ...         ...         ...         ...         ...
# 1713  2018-12-24  119.570000  120.139999  119.570000  120.019997  120.019997
# 1714  2018-12-26  120.620003  121.000000  119.570000  119.660004  119.660004
# 1715  2018-12-27  120.570000  120.900002  120.139999  120.570000  120.570000
# 1716  2018-12-28  120.800003  121.080002  120.720001  121.059998  121.059998
# 1717  2018-12-31  120.980003  121.260002  120.830002  121.250000  121.250000
#
# ...

# %%
Gold
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2011-12-15  154.740005  154.949997  151.710007  152.330002  152.330002
# 1     2011-12-16  154.309998  155.369995  153.899994  155.229996  155.229996
# 2     2011-12-19  155.479996  155.860001  154.360001  154.869995  154.869995
# 3     2011-12-20  156.820007  157.429993  156.580002  156.979996  156.979996
# 4     2011-12-21  156.979996  157.529999  156.130005  157.160004  157.160004
# ...          ...         ...         ...         ...         ...         ...
# 1713  2018-12-24  119.570000  120.139999  119.570000  120.019997  120.019997
# 1714  2018-12-26  120.620003  121.000000  119.570000  119.660004  119.660004
# 1715  2018-12-27  120.570000  120.900002  120.139999  120.570000  120.570000
# 1716  2018-12-28  120.800003  121.080002  120.720001  121.059998  121.059998
# 1717  2018-12-31  120.980003  121.260002  120.830002  121.250000  121.250000
#
# ...

# %%
Oil
# Out:
#             Date   Price    Open    High     Low     Vol.
# 0     2011-12-01  100.20  100.51  101.17   98.87  275.86K
# 1     2011-12-02  100.96  100.00  101.56   99.76  245.92K
# 2     2011-12-05  100.99  101.23  102.44  100.24  239.38K
# 3     2011-12-06  101.28  100.45  101.42  100.20  217.03K
# 4     2011-12-07  100.49  101.11  101.94   99.67  330.53K
# ...          ...     ...     ...     ...     ...      ...
# 1839  2018-12-25   43.16   43.00   43.25   42.88        -
# 1840  2018-12-26   46.22   42.85   47.00   42.52  698.41K
# 1841  2018-12-27   44.61   46.58   46.70   44.37  665.59K
# 1842  2018-12-28   45.33   45.44   46.22   44.42  564.39K
# 1843  2018-12-31   45.41   45.22   46.53   44.73  476.97K
#
# [1844 rows x 6 columns]

# %%
#Create Gold subset with four columns.
gold_subset = pd.read_csv('gold_stocks_price.csv', usecols=['Date', 'Open', 'High', 'Low'])
print(gold_subset)
# Out:
#             Date        Open        High         Low
# 0     2011-12-15  154.740005  154.949997  151.710007
# 1     2011-12-16  154.309998  155.369995  153.899994
# 2     2011-12-19  155.479996  155.860001  154.360001
# 3     2011-12-20  156.820007  157.429993  156.580002
# 4     2011-12-21  156.979996  157.529999  156.130005
# ...          ...         ...         ...         ...
# 1713  2018-12-24  119.570000  120.139999  119.570000
# 1714  2018-12-26  120.620003  121.000000  119.570000
# 1715  2018-12-27  120.570000  120.900002  120.139999
# 1716  2018-12-28  120.800003  121.080002  120.720001
# 1717  2018-12-31  120.980003  121.260002  120.830002
#
# [1718 rows x 4 columns]

# %%
#Create Gold subset with four columns.
gold_subset_2 = Gold[['Date', 'Open', 'High', 'Low']]
print(gold_subset_2)
# Out:
#             Date        Open        High         Low
# 0     2011-12-15  154.740005  154.949997  151.710007
# 1     2011-12-16  154.309998  155.369995  153.899994
# 2     2011-12-19  155.479996  155.860001  154.360001
# 3     2011-12-20  156.820007  157.429993  156.580002
# 4     2011-12-21  156.979996  157.529999  156.130005
# ...          ...         ...         ...         ...
# 1713  2018-12-24  119.570000  120.139999  119.570000
# 1714  2018-12-26  120.620003  121.000000  119.570000
# 1715  2018-12-27  120.570000  120.900002  120.139999
# 1716  2018-12-28  120.800003  121.080002  120.720001
# 1717  2018-12-31  120.980003  121.260002  120.830002
#
# [1718 rows x 4 columns]

# %%
# Slice the gold_subset to 500 rows
gold_subset_3 = gold_subset_2.iloc[:500]

# %%
print(gold_subset_3.shape)
print(gold_subset_3.dtypes)
# Out:
# (500, 4)
# Date     object
# Open    float64
# High    float64
# Low     float64
# dtype: object

# %%
print(gold_subset_2.shape)
# Out:
# (1718, 4)

# %%
print(gold_subset_2.dtypes)
# Out:
# Date     object
# Open    float64
# High    float64
# Low     float64
# dtype: object

# %%
# Number of missing values.
gold_subset_2.isnull().sum()
# Out:
# Date    0
# Open    0
# High    0
# Low     0
# dtype: int64

# %%
#Min-max column values (gold).
print(gold_subset_2['Open'].max())
print(gold_subset_2['Open'].min())
# Out:
# 173.199997
# 100.919998

# %%
print(gold_subset_2['High'].max())
print(gold_subset_2['High'].min())
# Out:
# 174.070007
# 100.989998

# %%
print(gold_subset_2['Low'].max())
print(gold_subset_2['Low'].min())
# Out:
# 172.919998
# 100.230003

# %%
#Create Oil subset with four columns.
oil_subset = Oil[['Date', 'Open', 'High', 'Low']]
print(oil_subset)
# Out:
#             Date    Open    High     Low
# 0     2011-12-01  100.51  101.17   98.87
# 1     2011-12-02  100.00  101.56   99.76
# 2     2011-12-05  101.23  102.44  100.24
# 3     2011-12-06  100.45  101.42  100.20
# 4     2011-12-07  101.11  101.94   99.67
# ...          ...     ...     ...     ...
# 1839  2018-12-25   43.00   43.25   42.88
# 1840  2018-12-26   42.85   47.00   42.52
# 1841  2018-12-27   46.58   46.70   44.37
# 1842  2018-12-28   45.44   46.22   44.42
# 1843  2018-12-31   45.22   46.53   44.73
#
# [1844 rows x 4 columns]

# %%
# Slice the oil_subset to 500 rows
oil_subset_2 = oil_subset.iloc[:500]

# %%
print(oil_subset_2.shape)
print(oil_subset_2.dtypes)
# Out:
# (500, 4)
# Date     object
# Open    float64
# High    float64
# Low     float64
# dtype: object

# %%
print(oil_subset.shape)
print(oil_subset.dtypes)
# Out:
# (1844, 4)
# Date     object
# Open    float64
# High    float64
# Low     float64
# dtype: object

# %%
# Number of missing values.
oil_subset.isnull().sum()
# Out:
# Date    0
# Open    0
# High    0
# Low     0
# dtype: int64

# %%
#Min-max column values (oil).
print(oil_subset['Open'].max())
print(oil_subset['Open'].min())
# Out:
# 110.28
# 27.3

# %%
print(oil_subset['High'].max())
print(oil_subset['High'].min())
# Out:
# 112.24
# 27.48

# %%
print(oil_subset['Low'].max())
print(oil_subset['Low'].min())
# Out:
# 109.11
# 26.05

# %%
#Perform statistical analysis on gold subset.
gold_subset_2.describe()
# Out:
#               Open         High          Low
# count  1718.000000  1718.000000  1718.000000
# mean    127.323434   127.854237   126.777695
# std      17.526993    17.631189    17.396513
# min     100.919998   100.989998   100.230003
# 25%     116.220001   116.540001   115.739998
# 50%     121.915001   122.325001   121.369999
# 75%     128.427494   129.087498   127.840001
# max     173.199997   174.070007   172.919998

# %%
#Overiew of gold statistical analysis.
#As mean is greater than median, the gold data appears to be right skewed.

# %%
#Perform statistical analysis on oil subset.
oil_subset.describe()
# Out:
#               Open         High          Low
# count  1844.000000  1844.000000  1844.000000
# mean     70.481242    71.319707    69.552413
# std      23.485367    23.505822    23.424742
# min      27.300000    27.480000    26.050000
# 25%      49.077500    49.710000    48.240000
# 50%      65.295000    66.020000    64.315000
# 75%      94.530000    95.592500    93.652500
# max     110.280000   112.240000   109.110000

# %%
#Overiew of oil statistical analysis.
#As mean is greater than median, the oil data appears to be right skewed.

# %%
# Determine the shape of the data set.
print(Gold.shape)
print(Gold.dtypes)
# Out:
# (1718, 81)
# Date              object
# Open             float64
# High             float64
# Low              float64
# Close            float64
#                   ...
# USO_High         float64
# USO_Low          float64
# USO_Close        float64
# USO_Adj Close    float64
# USO_Volume         int64
# Length: 81, dtype: object

# %%
Gold.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2011-12-15  154.740005  154.949997  151.710007  152.330002  152.330002
# 1  2011-12-16  154.309998  155.369995  153.899994  155.229996  155.229996
# 2  2011-12-19  155.479996  155.860001  154.360001  154.869995  154.869995
# 3  2011-12-20  156.820007  157.429993  156.580002  156.979996  156.979996
# 4  2011-12-21  156.979996  157.529999  156.130005  157.160004  157.160004
#
#      Volume     SP_open     SP_high      SP_low  ...    GDX_Low  GDX_Close  \
# 0  21521900  123.029999  123.199997  121.989998  ...  51.570000  51.680000
# 1  18124300  122.230003  122.949997  121.300003  ...  52.040001  52.680000
# 2  12547200  122.059998  122.320000  120.029999  ...  51.029999  51.169998
# 3   9136300  122.180000  124.139999  120.370003  ...  52.369999  52.990002
# 4  11996100  123.930000  124.360001  122.750000  ...  52.419998  52.959999
#
# ...

# %%
my_list = Gold.columns.values.tolist()
print(my_list)
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'SP_open', 'SP_high', 'SP_low', 'SP_close', 'SP_Ajclose', 'SP_volume', 'DJ_open', 'DJ_high', 'DJ_low', 'DJ_close', 'DJ_Ajclose', 'DJ_volume', 'EG_open', 'EG_high', 'EG_low', 'EG_close', 'EG_Ajclose', 'EG_volume', 'EU_Price', 'EU_open', 'EU_high', 'EU_low', 'EU_Trend', 'OF_Price', 'OF_Open', 'OF_High', 'OF_Low', 'OF_Volume', 'OF_Trend', 'OS_Price', 'OS_Open', 'OS_High', 'OS_Low', 'OS_Trend', 'SF_Price', 'SF_Open', 'SF_High', 'SF_Low', 'SF_Volume', 'SF_Trend', 'USB_Price', 'USB_Open', 'USB_High', 'USB_Low', 'USB_Trend', 'PLT_Price', 'PLT_Open', 'PLT_High', 'PLT_Low', 'PLT_Trend', 'PLD_Price', 'PLD_Open', 'PLD_High', 'PLD_Low', 'PLD_Trend', 'RHO_PRICE', 'USDI_Price', 'USDI_Open', 'USDI_High', 'USDI_Low', 'USDI_Volume', 'USDI_Trend', 'GDX_Open', 'GDX_High', 'GDX_Low', 'GDX_Close', 'GDX_Adj Close', 'GDX_Volume', 'USO_Open', 'USO_High', 'USO_Low', 'USO_Close', 'USO_Adj Close', 'USO_Volume']

# %%
print(Gold.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'SP_open', 'SP_high', 'SP_low', 'SP_close', 'SP_Ajclose', 'SP_volume',
#        'DJ_open', 'DJ_high', 'DJ_low', 'DJ_close', 'DJ_Ajclose', 'DJ_volume',
#        'EG_open', 'EG_high', 'EG_low', 'EG_close', 'EG_Ajclose', 'EG_volume',
#        'EU_Price', 'EU_open', 'EU_high', 'EU_low', 'EU_Trend', 'OF_Price',
#        'OF_Open', 'OF_High', 'OF_Low', 'OF_Volume', 'OF_Trend', 'OS_Price',
#        'OS_Open', 'OS_High', 'OS_Low', 'OS_Trend', 'SF_Price', 'SF_Open',
#        'SF_High', 'SF_Low', 'SF_Volume', 'SF_Trend', 'USB_Price', 'USB_Open',
#        'USB_High', 'USB_Low', 'USB_Trend', 'PLT_Price', 'PLT_Open', 'PLT_High',
#        'PLT_Low', 'PLT_Trend', 'PLD_Price', 'PLD_Open', 'PLD_High', 'PLD_Low',
#        'PLD_Trend', 'RHO_PRICE', 'USDI_Price', 'USDI_Open', 'USDI_High',
#        'USDI_Low', 'USDI_Volume', 'USDI_Trend', 'GDX_Open', 'GDX_High',
# ...

# %%
#Create Stocks subset with stocks volume columns.
stocks_subset = Gold[['Date', 'Open', 'High', 'Low', 'Volume', 'SP_volume','DJ_volume', 'EG_volume', 'OF_Volume', 'SF_Volume', 'USDI_Volume', 
                      'GDX_Volume', 'USO_Volume']]
print(stocks_subset)
# Out:
#             Date        Open        High         Low    Volume  SP_volume  \
# 0     2011-12-15  154.740005  154.949997  151.710007  21521900  199109200
# 1     2011-12-16  154.309998  155.369995  153.899994  18124300  220481400
# 2     2011-12-19  155.479996  155.860001  154.360001  12547200  183903000
# 3     2011-12-20  156.820007  157.429993  156.580002   9136300  225418100
# 4     2011-12-21  156.979996  157.529999  156.130005  11996100  194230900
# ...          ...         ...         ...         ...       ...        ...
# 1713  2018-12-24  119.570000  120.139999  119.570000   9736400  147311600
# 1714  2018-12-26  120.620003  121.000000  119.570000  14293500  218485400
# 1715  2018-12-27  120.570000  120.900002  120.139999  11874400  186267300
# 1716  2018-12-28  120.800003  121.080002  120.720001   6864700  153100200
# 1717  2018-12-31  120.980003  121.260002  120.830002   8449400  144299400
#
#       DJ_volume  EG_volume  OF_Volume  SF_Volume  USDI_Volume  GDX_Volume  \
# ...

# %%
#Which stocks were sold with the highest volume?
#Which stocks were sold with the lowest volume?
stocks_subset.describe()
# Out:
#               Open         High          Low        Volume     SP_volume  \
# count  1718.000000  1718.000000  1718.000000  1.718000e+03  1.718000e+03
# mean    127.323434   127.854237   126.777695  8.446327e+06  1.098026e+08
# std      17.526993    17.631189    17.396513  4.920731e+06  4.925110e+07
# min     100.919998   100.989998   100.230003  1.501600e+06  2.785650e+07
# 25%     116.220001   116.540001   115.739998  5.412925e+06  7.387085e+07
# 50%     121.915001   122.325001   121.369999  7.483900e+06  9.972020e+07
# 75%     128.427494   129.087498   127.840001  1.020795e+07  1.351161e+08
# max     173.199997   174.070007   172.919998  9.380420e+07  5.072443e+08
#
#           DJ_volume     EG_volume      OF_Volume      SF_Volume  \
# count  1.718000e+03  1.718000e+03    1718.000000    1718.000000
# mean   1.779131e+08  1.136074e+06  225958.585565   26912.462165
# std    1.212753e+08  7.301289e+05   88844.540581   21880.969122
# ...

# %% [markdown]
# Stock with the highest mean (and highest absolute) daily volume sold is DJ. Stock with the lowest mean (and lowest absolute) daily volume sold is SF.

# %%
#Find the period when the gold prices dip to the lowest.
gold_subset_2['Low'].min()
# Out:
# 100.230003

# %%
Lowest_gold_price = gold_subset_2[gold_subset_2['Low'] == 100.230003]
Lowest_gold_price
# Out:
#            Date        Open        High         Low
# 964  2015-12-17  100.919998  100.989998  100.230003

# %% [markdown]
# Lowest gold prices on 17th December 2015

# %%
#Find the period when the gold prices rise to the highest.
gold_subset_2['High'].max()
# Out:
# 174.070007

# %%
highest_gold_price = gold_subset_2[gold_subset_2['High'] == 174.070007]
highest_gold_price
# Out:
#            Date        Open        High         Low
# 199  2012-10-04  173.199997  174.070007  172.919998

# %% [markdown]
# Highest gold prices on 4th October 2012

# %%
#Which stocks were sold with the lowest volume?
stocks_subset.min()
# Out:
# Date           2011-12-15
# Open           100.919998
# High           100.989998
# Low            100.230003
# Volume            1501600
# SP_volume        27856500
# DJ_volume         8410000
# EG_volume          164500
# OF_Volume           11520
# SF_Volume              40
# USDI_Volume            60
# GDX_Volume        4729000
# USO_Volume        1035100
# dtype: object

# %%
#Which stocks were sold with the highest volume?
stocks_subset.max()
# Out:
# Date           2018-12-31
# Open           173.199997
# High           174.070007
# Low            172.919998
# Volume           93804200
# SP_volume       507244300
# DJ_volume       900510000
# EG_volume        10061200
# OF_Volume          567760
# SF_Volume          203730
# USDI_Volume        142820
# GDX_Volume      232153600
# USO_Volume      110265700
# dtype: object

# %%
#Find the period when the oil prices dip to the lowest.
oil_subset['Low'].min()
# Out:
# 26.05

# %%
Lowest_oil_price = oil_subset[oil_subset['Low'] == 26.05]
Lowest_oil_price
# Out:
#             Date   Open   High    Low
# 1082  2016-02-11  27.34  27.48  26.05

# %% [markdown]
# Lowest oil price is on 11th February 2016

# %%
#Find the period when the oil prices rise to the highest.
oil_subset['High'].max()
# Out:
# 112.24

# %%
Highest_oil_price = oil_subset[oil_subset['High'] == 112.24]
Highest_oil_price
# Out:
#            Date    Open    High     Low
# 440  2013-08-28  109.22  112.24  109.11

# %% [markdown]
# Highest oil price is on 28th August 2013

# %%
oil_subset.describe()
# Out:
#               Open         High          Low
# count  1844.000000  1844.000000  1844.000000
# mean     70.481242    71.319707    69.552413
# std      23.485367    23.505822    23.424742
# min      27.300000    27.480000    26.050000
# 25%      49.077500    49.710000    48.240000
# 50%      65.295000    66.020000    64.315000
# 75%      94.530000    95.592500    93.652500
# max     110.280000   112.240000   109.110000

# %%
gold_subset_2.sort_values(by=['Low'], inplace=True)

gold_subset_2
# Out:
# C:\Users\Jon D\AppData\Local\Temp\ipykernel_7308\2343972294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gold_subset_2.sort_values(by=['Low'], inplace=True)
#            Date        Open        High         Low
# 964  2015-12-17  100.919998  100.989998  100.230003
# 953  2015-12-02  101.349998  101.349998  100.529999
# 954  2015-12-03  101.230003  101.970001  100.849998
# 950  2015-11-27  101.010002  101.620003  100.989998
# 965  2015-12-18  101.349998  102.529999  101.300003
# ..          ...         ...         ...         ...
# 46   2012-02-24  172.630005  173.039993  172.000000
# 200  2012-10-05  172.869995  173.369995  172.009995
# 45   2012-02-23  172.690002  173.770004  172.279999
# 48   2012-02-28  172.839996  174.000000  172.600006
# ...

# %% [markdown]
# Find the period when the gold prices dip to the lowest:
#
# Gold prices dip to the lowest level on 17th December 2015

# %%
#Find the period when SF volume was lowest:

stocks_subset.sort_values(by=['SF_Volume'], inplace=True)

stocks_subset
# Out:
# C:\Users\Jon D\AppData\Local\Temp\ipykernel_7308\2582533593.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stocks_subset.sort_values(by=['SF_Volume'], inplace=True)
#             Date        Open        High         Low    Volume  SP_volume  \
# 1596  2018-07-05  118.919998  119.330002  118.769997   4951900   56925900
# 1057  2016-05-04  122.849998  123.230003  121.510002   9327400   92243800
# 644   2014-09-05  121.830002  122.059998  121.629997   3490100  102177000
# 1638  2018-09-05  113.360001  113.440002  113.120003   4459200   72452400
# 1554  2018-05-04  124.099998  124.650002  124.000000   5883600   91222100
# ...          ...         ...         ...         ...       ...        ...
# 325   2013-04-12  148.649994  148.850006  143.429993  55601800  116359900
# ...

# %% [markdown]
# Minimum SF stock volume traded on 2014-09-05, 2016-05-04 and 2018-07-05.

# %%
#Find the period when DJ volume was lowest:

stocks_subset.sort_values(by=['DJ_volume'], inplace=True, ascending=False)

stocks_subset
# Out:
# C:\Users\Jon D\AppData\Local\Temp\ipykernel_7308\3436089172.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stocks_subset.sort_values(by=['DJ_volume'], inplace=True, ascending=False)
#             Date        Open        High         Low    Volume  SP_volume  \
# 1712  2018-12-21  119.190002  119.250000  118.570000  13629800  255345600
# 1493  2018-02-06  126.540001  126.550003  125.220001  17672500  355026800
# 1496  2018-02-09  124.650002  125.139999  124.389999  14140700  283565300
# 1492  2018-02-05  126.820000  127.309998  126.440002  13596300  294681800
# 1583  2018-06-15  122.180000  122.199997  120.830002  14537000  120041600
# ...          ...         ...         ...         ...       ...        ...
# 722   2014-12-30  114.989998  116.260002  114.900002   7987300   73540800
# ...

# %% [markdown]
# Maximum DJ stock volume traded on 2018-12-21

# %%
oil_subset.sort_values(by=['Low'], inplace=True)

oil_subset
# Out:
# C:\Users\Jon D\AppData\Local\Temp\ipykernel_7308\993049954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oil_subset.sort_values(by=['Low'], inplace=True)
#             Date    Open    High     Low
# 1082  2016-02-11   27.34   27.48   26.05
# 1066  2016-01-20   28.33   28.58   26.19
# 1083  2016-02-12   27.30   29.66   26.95
# 1081  2016-02-10   28.36   29.22   27.24
# 1080  2016-02-09   30.17   30.61   27.74
# ...          ...     ...     ...     ...
# 441   2013-08-29  109.53  110.07  107.72
# 57    2012-02-24  108.66  109.95  107.95
# 447   2013-09-06  108.52  110.70  108.12
# 448   2013-09-09  110.28  110.46  108.76
# 440   2013-08-28  109.22  112.24  109.11
#
# [1844 rows x 4 columns]

# %% [markdown]
# Find the period when the oil prices dip to the lowest:
#
# Oil prices dip to the lowest level on 11th February 2016

# %%
oil_subset.sort_values(by=['High'], inplace=True, ascending=False)

oil_subset
# Out:
# C:\Users\Jon D\AppData\Local\Temp\ipykernel_7308\1066160983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oil_subset.sort_values(by=['High'], inplace=True, ascending=False)
#             Date    Open    High     Low
# 440   2013-08-28  109.22  112.24  109.11
# 447   2013-09-06  108.52  110.70  108.12
# 61    2012-03-01  106.82  110.55  106.55
# 448   2013-09-09  110.28  110.46  108.76
# 441   2013-08-29  109.53  110.07  107.72
# ...          ...     ...     ...     ...
# 1083  2016-02-12   27.30   29.66   26.95
# 1081  2016-02-10   28.36   29.22   27.24
# 1084  2016-02-14   29.06   29.18   28.97
# 1066  2016-01-20   28.33   28.58   26.19
# 1082  2016-02-11   27.34   27.48   26.05
#
# [1844 rows x 4 columns]

# %% [markdown]
# Find the period when the oil prices rise to the highest:
#
# Oil prices rise to the highest level on 28th August 2013
